# %% [markdown]
# # WORLD HAPPINESS REPORT

# %% [markdown]
# Description:

# %% [markdown]
# The World Happiness Report is a landmark survey of the state of global happiness.The report continues to gain global recognition as governments, organizations and civil society increasingly use happiness indicators to inform their policy-making decisions. Leading experts across fields – economics, psychology, survey analysis, national statistics, health, public policy and more – describe how measurements of well-being can be used effectively to assess the progress of nations. The reports review the state of happiness in the world today and show how the new science of happiness explains personal and national variations in happiness.

# %% [markdown]
# The happiness scores and rankings use data from the Gallup World Poll. The scores are based on answers to the main life evaluation question asked in the poll. This question, known as the Cantril ladder, asks respondents to think of a ladder with the best possible life for them being a 10 and the worst possible life being a 0 and to rate their own current lives on that scale.The columns following the happiness score estimate the extent to which each of six factors – economic production, social support, life expectancy, freedom, absence of corruption, and generosity – contribute to making life evaluations higher in each country than they are in Dystopia, a hypothetical country that has values equal to the world’s lowest national averages for each of the six factors. They have no impact on the total score reported for each country, but they do explain why some countries rank higher than others.

# %% [markdown]
# Dystopia:
# It is an imaginary country that has the world’s least-happy people. The purpose in establishing Dystopia is to have a benchmark against which all countries can be favorably compared (no country performs more poorly than Dystopia) in terms of each of the six key variables, thus allowing each sub-bar to be of positive width. The lowest scores observed for the six key variables, therefore, characterize Dystopia. Since life would be very unpleasant in a country with the world’s lowest incomes, lowest life expectancy, lowest generosity, most corruption, least freedom and least social support, it is referred to as “Dystopia,” in contrast to Utopia.

# %% [markdown]
# The residuals, or unexplained components, differ for each country, reflecting the extent to which the six variables either over- or under-explain average life evaluations.

# %% [markdown]
# The following columns: GDP per Capita, Family, Life Expectancy, Freedom, Generosity, Trust Government Corruption describe the extent to which these factors contribute in evaluating the happiness in each country.
# The Dystopia Residual metric actually is the Dystopia Happiness Score(1.85) + the Residual value or the unexplained value for each country as stated in the previous answer.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('world_happiness_score.csv')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#Checking dimension of data
df.shape
# Out:
# (158, 12)

# %%
#Column names
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
#Checking for missing values
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
sns.heatmap(df.isnull())

# %% [markdown]
# There are no null values in our data.

# %%
#checking the distribution of data
df.hist(bins=50,figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020301CFEEB0>,
# ...
#       dtype=object)

# %%
#Lets see the top 5 happiest countries
df.groupby('Country')['Happiness Score'].max().sort_values(ascending=False).head(5).plot(kind='bar', figsize=(12,6),color='green')
plt.title('Top 5 happiest countries')
plt.show()

# %%
#Least 5 happy countries
df.groupby('Country')['Happiness Score'].max().sort_values(ascending=False).tail(5).plot(kind='bar', figsize=(12,6),color='green')
plt.title('Top 5 Saddest countries')
plt.show()

# %% [markdown]
# Switzerland is the happiest country.
#
# Togo is the saddest or the least happy country.

# %%
#Top 10 countries with higghest GDP per capita
df.groupby('Country')['Economy (GDP per Capita)'].max().sort_values(ascending=False).head(10).plot(kind='bar', figsize=(20,6),color='limegreen')
plt.title('Top 10 countries with higghest GDP per capita')
plt.show()

# %%
# 10 countries with lowest GDP per capita
df.groupby('Country')['Economy (GDP per Capita)'].max().sort_values(ascending=False).tail(10).plot(kind='bar', figsize=(20,6),color='limegreen')
plt.title('10 countries with lowest GDP per capita')
plt.show()

# %% [markdown]
# Qatar have the highest economy.
#
# Congo(kinshasa) have the lowest economy.

# %%
#Grouping by Family- top 10
df.groupby('Country')['Family'].max().sort_values(ascending=False).head(10).plot(kind='bar',figsize=(20,6))
plt.title('Top 10 countries with highest family value')
plt.show()

# %%
#Grouping by Family- least 10
df.groupby('Country')['Family'].max().sort_values(ascending=False).tail(10).plot(kind='bar',figsize=(20,6))
plt.title('Least 10 countries accoding to family')
plt.show()

# %% [markdown]
# Iceland have the highest value for family.
#
# Central African Republic have the lowest value for family

# %%
#Top 10 countries with high health (life expectancy)
df.groupby('Country')['Health (Life Expectancy)'].max().sort_values(ascending=False).head(10).plot(kind='bar', figsize=(20,6))
plt.title('Top 10 countries with high health (life expectancy)')
plt.show()

# %%
#10 countries with lowest health (life expectancy)
df.groupby('Country')['Health (Life Expectancy)'].max().sort_values(ascending=False).tail(10).plot(kind='bar', figsize=(20,6))
plt.title('10 countries with lowest health (life expectancy)')
plt.show()

# %% [markdown]
# Singapore have the highest healthy life expentancy.
#
# Sierra Leone have the lowest healthy life expentancy.

# %%
#Top 10 countries with high freedom
df.groupby('Country')['Freedom'].max().sort_values(ascending=False).head(10).plot(kind='bar',figsize=(20,6))
plt.title('Countries with high freedom')
plt.show()

# %%
# 10 countries with least freedom
df.groupby('Country')['Freedom'].max().sort_values(ascending=False).tail(10).plot(kind='bar',figsize=(20,6))
plt.title('Countries with least freedom')
plt.show()

# %% [markdown]
# Norway have the highest freedom.
#
# Iraq have the lowest freedom.

# %%
# 10 countries with highest Government Corruption.
df.groupby('Country')['Trust (Government Corruption)'].max().sort_values(ascending=False).head(10).plot(kind='bar',figsize=(20,6))
plt.title('Countries with highest government corruption')
plt.show()

# %%
# 10 countries with least Government Corruption.
df.groupby('Country')['Trust (Government Corruption)'].max().sort_values(ascending=False).tail(10).plot(kind='bar',figsize=(20,6))
plt.title('Countries with least government corruption')
plt.show()

# %% [markdown]
# Rwanda have the highest government corruption rate.
#
# Indonesia have the lowest corruption rate.

# %%
# 10 countries with highest Generosity.
df.groupby('Country')['Generosity'].max().sort_values(ascending=False).head(10).plot(kind='bar',figsize=(20,6))
plt.title('Countries with highest Generosity')
plt.show()

# %%
# 10 countries with lowest Generosity.
df.groupby('Country')['Generosity'].max().sort_values(ascending=False).tail(10).plot(kind='bar',figsize=(20,6))
plt.title('Countries with lowest Generosity')
plt.show()

# %% [markdown]
# Myanmar have the highest Generosity.
#
# Greece have the lowest Generosity.

# %% [markdown]
# Let's find correlation between the happiness score and the factors affecting it i.e,Economy (GDP per Capita),Family,Health (Life Expectancy),Freedom,Trust(Government Corruption) and Generosity.

# %%
df_corr=df[['Happiness Score','Economy (GDP per Capita)', 'Family',
       'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
       'Generosity']]

# %%
df_corr.head()
# Out:
#    Happiness Score  Economy (GDP per Capita)   Family  \
# 0            7.587                   1.39651  1.34951
# 1            7.561                   1.30232  1.40223
# 2            7.527                   1.32548  1.36058
# 3            7.522                   1.45900  1.33095
# 4            7.427                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity
# 0     0.29678
# 1     0.43630
# 2     0.34139
# 3     0.34699
# 4     0.45811

# %%
corr=df_corr.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr,annot=True)
plt.show()

# %% [markdown]
# We can see that there are strong positive correlation of happiness score with economy (GDP per capita), family and health (life exceptancy.)

# %%
columns=['Economy (GDP per Capita)', 'Family',
       'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
       'Generosity']
for i in columns:
    plt.figure(figsize=(10,4))
    plt.scatter(df[i],df['Happiness Score']) 
    plt.xlabel(i)
    plt.ylabel('Happiness Score')
    plt.show()

# %% [markdown]
# From the above figures we can see that, except government corruption and generosity every other thing i.e, economy, health life expectancy, family, freedom makes people happy of that particular country.
